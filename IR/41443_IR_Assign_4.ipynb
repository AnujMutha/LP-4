# %% [markdown]
# # 41422- Isha Gaikwad IR_ASSIGNMENT4

# %%
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

# %%
logging.basicConfig(
    format='%(asctime)s %(levelname)s:%(message)s',
    level=logging.INFO)

# %%
class Crawler:

    def __init__(self, urls=[]):
        self.visited_urls = []
        self.urls_to_visit = urls

    def download_url(self, url):
        return requests.get(url).text

    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('a'):
            path = link.get('href')
            if path and path.startswith('/'):
                path = urljoin(url, path)
            yield path

    def add_url_to_visit(self, url):
        if url not in self.visited_urls and url not in self.urls_to_visit:
            self.urls_to_visit.append(url)

    def crawl(self, url):
        html = self.download_url(url)
        for url in self.get_linked_urls(url, html):
            self.add_url_to_visit(url)

    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            logging.info(f'Crawling: {url}')
            try:
                self.crawl(url)
            except Exception:
                logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)

# %%
Crawler(urls=['https://www.imdb.com/']).run()
# Out:
# 2022-10-26 17:00:20,401 INFO:Crawling: https://www.imdb.com/
# 2022-10-26 17:00:22,411 INFO:Crawling: https://www.imdb.com/?ref_=nv_home
# 2022-10-26 17:00:23,977 INFO:Crawling: https://www.imdb.com/calendar/?ref_=nv_mv_cal
# 2022-10-26 17:00:25,884 INFO:Crawling: https://www.imdb.com/chart/top/?ref_=nv_mv_250
# 2022-10-26 17:00:28,872 INFO:Crawling: https://www.imdb.com/chart/moviemeter/?ref_=nv_mv_mpm
# 2022-10-26 17:00:30,857 INFO:Crawling: https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# 2022-10-26 17:00:32,160 INFO:Crawling: https://www.imdb.com/chart/boxoffice/?ref_=nv_ch_cht
# 2022-10-26 17:00:33,716 INFO:Crawling: https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# 2022-10-26 17:00:36,277 INFO:Crawling: https://www.imdb.com/news/movie/?ref_=nv_nw_mv
# 2022-10-26 17:00:37,525 INFO:Crawling: https://www.imdb.com/india/toprated/?ref_=nv_mv_in
# 2022-10-26 17:00:38,919 INFO:Crawling: https://www.imdb.com/whats-on-tv/?ref_=nv_tv_ontv
# 2022-10-26 17:00:40,006 INFO:Crawling: https://www.imdb.com/chart/toptv/?ref_=nv_tvv_250
# 2022-10-26 17:00:42,611 INFO:Crawling: https://www.imdb.com/chart/tvmeter/?ref_=nv_tvv_mptv
# 2022-10-26 17:00:44,345 INFO:Crawling: https://www.imdb.com/feature/genre/
# 2022-10-26 17:00:45,580 INFO:Crawling: https://www.imdb.com/news/tv/?ref_=nv_nw_tv
# 2022-10-26 17:00:46,887 INFO:Crawling: https://www.imdb.com/india/tv?ref_=nv_tv_in
# 2022-10-26 17:00:48,738 INFO:Crawling: https://www.imdb.com/what-to-watch/?ref_=nv_watch
# 2022-10-26 17:00:49,839 INFO:Crawling: https://www.imdb.com/trailers/?ref_=nv_mv_tr
# 2022-10-26 17:00:50,998 INFO:Crawling: https://www.imdb.com/originals/?ref_=nv_sf_ori
# 2022-10-26 17:00:52,051 INFO:Crawling: https://www.imdb.com/imdbpicks/?ref_=nv_pi
# 2022-10-26 17:00:53,275 INFO:Crawling: https://www.imdb.com/podcasts/?ref_=nv_pod
# 2022-10-26 17:00:54,336 INFO:Crawling: https://www.imdb.com/oscars/?ref_=nv_ev_acd
# 2022-10-26 17:00:55,577 INFO:Crawling: https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# 2022-10-26 17:00:57,863 INFO:Crawling: https://www.imdb.com/search/title/?count=100&groups=oscar_best_picture_winners&sort=year%2Cdesc&ref_=nv_ch_osc
# 2022-10-26 17:01:00,868 INFO:Crawling: https://www.imdb.com/emmys/?ref_=nv_ev_rte
# 2022-10-26 17:01:02,124 INFO:Crawling: https://www.imdb.com/starmeterawards/?ref_=nv_ev_sma
# 2022-10-26 17:01:03,467 INFO:Crawling: https://www.imdb.com/comic-con/?ref_=nv_ev_comic
# 2022-10-26 17:01:04,764 INFO:Crawling: https://www.imdb.com/nycc/?ref_=nv_ev_nycc
# 2022-10-26 17:01:05,918 INFO:Crawling: https://www.imdb.com/sundance/?ref_=nv_ev_sun
# 2022-10-26 17:01:07,151 INFO:Crawling: https://www.imdb.com/toronto/?ref_=nv_ev_tor
# 2022-10-26 17:01:08,192 INFO:Crawling: https://www.imdb.com/awards-central/?ref_=nv_ev_awrd
# 2022-10-26 17:01:09,209 INFO:Crawling: https://www.imdb.com/festival-central/?ref_=nv_ev_fc
# 2022-10-26 17:01:10,243 INFO:Crawling: https://www.imdb.com/event/all/?ref_=nv_ev_all
# 2022-10-26 17:01:11,264 INFO:Crawling: https://www.imdb.com/feature/bornondate/?ref_=nv_cel_brn
# 2022-10-26 17:01:12,707 INFO:Crawling: https://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn
# 2022-10-26 17:01:14,844 INFO:Crawling: https://www.imdb.com/search/name/?match_all=true&ref_=nv_cel_m
# 2022-10-26 17:01:16,670 INFO:Crawling: https://www.imdb.com/news/celebrity/?ref_=nv_cel_nw
# 2022-10-26 17:01:17,609 INFO:Crawling: https://help.imdb.com/imdb?ref_=cons_nb_hlp
# 2022-10-26 17:01:18,981 INFO:Crawling: https://contribute.imdb.com/czone?ref_=nv_cm_cz
# 2022-10-26 17:01:20,396 INFO:Crawling: https://www.imdb.com/poll/?ref_=nv_cm_pl
# 2022-10-26 17:01:21,748 INFO:Crawling: https://pro.imdb.com?ref_=cons_nb_hm&rf=cons_nb_hm
# 2022-10-26 17:01:24,081 INFO:Crawling: https://www.imdb.com/search/
# 2022-10-26 17:01:24,844 INFO:Crawling: https://pro.imdb.com/login/ap?u=/login/lwa&imdbPageAction=signUp&rf=cons_nb_hm&ref_=cons_nb_hm
# 2022-10-26 17:01:25,150 INFO:Crawling: https://www.imdb.com/list/watchlist?ref_=nv_usr_wl_all_0
# 2022-10-26 17:01:46,910 INFO:Crawling: https://www.imdb.com/festival-central/outfest-legacy-gala/rg1025678080/mediaviewer/rm1055393537?ref_=hm_edcft_csegout_ft_ps_13_t
# 2022-10-26 17:01:47,911 INFO:Crawling: https://www.imdb.com/gallery/rg1310890752/mediaviewer/rm717948673?ref_=hm_edcft_hp_ph_im_lesliej_15_i
# 2022-10-26 17:01:49,292 INFO:Crawling: https://www.imdb.com/gallery/rg1310890752/mediaviewer/rm717948673?ref_=hm_edcft_hp_ph_im_lesliej_15_t
# 2022-10-26 17:01:49,913 INFO:Crawling: https://www.imdb.com/nycc/renew-cancel/ls063853872/mediaviewer/rm4278911745/?ref_=hm_edcft_ft_ls_rc_17_i
# 2022-10-26 17:01:50,676 INFO:Crawling: https://www.imdb.com/nycc/renew-cancel/ls063853872/mediaviewer/rm4278911745/?ref_=hm_edcft_ft_ls_rc_17_t
# 2022-10-26 17:01:51,545 INFO:Crawling: https://www.imdb.com/gallery/rg1624939264/mediaviewer/rm859899393?ref_=hm_edcft_hp_g_lp_19_i
# 2022-10-26 17:01:52,665 INFO:Crawling: https://www.imdb.com/gallery/rg1624939264/mediaviewer/rm859899393?ref_=hm_edcft_hp_g_lp_19_t
# 2022-10-26 17:01:53,515 INFO:Crawling: https://www.imdb.com/what-to-watch?ref_=hm_watch_btn
# 2022-10-26 17:01:54,859 INFO:Crawling: https://www.imdb.com/what-to-watch/watch-guides/?ref_=hm_watch_wchgd
# 2022-10-26 17:01:56,001 INFO:Crawling: https://www.imdb.com/what-to-watch/popular/?ref_=hm_watch_pop
# 2022-10-26 17:01:57,081 INFO:Crawling: https://www.imdb.com/video/vi2964440345/?listId=ls025720609&ref_=hm_edcio_og_bq_lyle_5_i
# 2022-10-26 17:01:58,051 INFO:Crawling: https://www.imdb.com/video/vi2964440345/?listId=ls025720609&ref_=hm_edcio_og_bq_lyle_5_t
# 2022-10-26 17:01:58,944 INFO:Crawling: https://www.imdb.com/video/vi1497874969/?listId=ls025720609&ref_=hm_edcio_og_nsp_ada_7_i
# 2022-10-26 17:01:59,941 INFO:Crawling: https://www.imdb.com/video/vi1497874969/?listId=ls025720609&ref_=hm_edcio_og_nsp_ada_7_t
# 2022-10-26 17:02:00,911 INFO:Crawling: https://www.imdb.com/video/vi843825689/?listId=ls025720609&ref_=hm_edcio_cseghhm_og_wtw_scaredyween_9_i
# 2022-10-26 17:02:02,225 INFO:Crawling: https://www.imdb.com/video/vi843825689/?listId=ls025720609&ref_=hm_edcio_cseghhm_og_wtw_scaredyween_9_t
# 2022-10-26 17:02:03,329 INFO:Crawling: https://www.imdb.com/video/vi1203356953/?listId=ls025720609&ref_=hm_edcio_og_bq_ba_11_i
# 2022-10-26 17:02:04,325 INFO:Crawling: https://www.imdb.com/video/vi1203356953/?listId=ls025720609&ref_=hm_edcio_og_bq_ba_11_t
# 2022-10-26 17:02:05,777 INFO:Crawling: https://www.imdb.com/video/vi1084343577/?listId=ls025720609&ref_=hm_edcio_og_ots_thewatcher_13_i
# 2022-10-26 17:02:06,720 INFO:Crawling: https://www.imdb.com/video/vi1084343577/?listId=ls025720609&ref_=hm_edcio_og_ots_thewatcher_13_t
# 2022-10-26 17:02:07,799 INFO:Crawling: https://www.imdb.com/video/vi1314636313/?listId=ls025720609&ref_=hm_edcio_og_ots_werewolfbynight_15_i
# 2022-10-26 17:02:08,825 INFO:Crawling: https://www.imdb.com/video/vi1314636313/?listId=ls025720609&ref_=hm_edcio_og_ots_werewolfbynight_15_t
# 2022-10-26 17:02:09,784 INFO:Crawling: https://www.imdb.com/video/vi1537328409/?listId=ls025720609&ref_=hm_edcio_org_banshees_ots_17_i
# 2022-10-26 17:02:10,724 INFO:Crawling: https://www.imdb.com/video/vi1537328409/?listId=ls025720609&ref_=hm_edcio_org_banshees_ots_17_t
# 2022-10-26 17:02:11,450 INFO:Crawling: https://www.imdb.com/video/vi331072793/?listId=ls025720609&ref_=hm_edcio_org_hweenends_ots_19_i
# 2022-10-26 17:02:12,358 INFO:Crawling: https://www.imdb.com/video/vi331072793/?listId=ls025720609&ref_=hm_edcio_org_hweenends_ots_19_t
# 2022-10-26 17:02:13,465 INFO:Crawling: https://www.imdb.com/video/vi3749757721/?listId=ls025720609&ref_=hm_edcio_og_rtcml_jlc_21_i
# 2022-10-26 17:02:14,410 INFO:Crawling: https://www.imdb.com/video/vi3749757721/?listId=ls025720609&ref_=hm_edcio_og_rtcml_jlc_21_t
# 2022-10-26 17:02:15,305 INFO:Crawling: https://help.imdb.com/article/imdb/general-information/why-do-i-need-to-enable-my-cookies-on-imdb/GWE3JQ8VUQDCFW3Q?ref_=helpsrall#
# 2022-10-26 17:02:16,249 INFO:Crawling: https://slyb.app.link/SKdyQ6A449
# 2022-10-26 17:02:16,596 INFO:Crawling: https://www.imdb.com/registration/signin?ref_=reg_ftr
# 2022-10-26 17:02:17,804 INFO:Crawling: https://www.tiktok.com/@imdb
# 2022-10-26 17:02:18,241 INFO:Crawling: https://instagram.com/imdb
# 2022-10-26 17:02:19,856 INFO:Crawling: https://twitter.com/imdb
# 2022-10-26 17:02:20,710 INFO:Crawling: https://youtube.com/imdb/
# 2022-10-26 17:02:21,614 INFO:Crawling: https://facebook.com/imdb
# 2022-10-26 17:02:22,160 INFO:Crawling: https://help.imdb.com/imdb
# 2022-10-26 17:02:23,013 INFO:Crawling: https://help.imdb.com/article/imdb/general-information/imdb-site-index/GNCX7BHNSPBTFALQ#so
# 2022-10-26 17:02:23,642 INFO:Crawling: https://pro.imdb.com?ref_=cons_tf_pro&rf=cons_tf_pro
# 2022-10-26 17:02:26,758 INFO:Crawling: https://www.boxofficemojo.com
# 2022-10-26 17:02:28,884 INFO:Crawling: https://developer.imdb.com/
# 2022-10-26 17:02:30,652 INFO:Crawling: https://www.imdb.com/pressroom/?ref_=ft_pr
# 2022-10-26 17:02:31,660 INFO:Crawling: https://advertising.amazon.com/resources/ad-specs/imdb/
# 2022-10-26 17:02:32,943 INFO:Crawling: https://www.amazon.jobs/en/teams/imdb
# 2022-10-26 17:02:33,943 INFO:Crawling: https://www.imdb.com/conditions?ref_=ft_cou
# 2022-10-26 17:02:34,953 INFO:Crawling: https://www.imdb.com/privacy?ref_=ft_pvc
# 2022-10-26 17:02:36,001 INFO:Crawling: https://www.amazon.com/b/?&node=5160028011
# 2022-10-26 17:02:37,879 INFO:Crawling: https://www.imdb.com/?ref_=nv_home
# 2022-10-26 17:02:39,369 INFO:Crawling: https://www.imdb.com/list/ls053181649/videoplayer/vi3064644889?ref_=hp_hp_e_14
# 2022-10-26 17:02:40,993 INFO:Crawling: https://www.imdb.com/list/ls053181649/videoplayer/vi1203356953?ref_=hp_hp_e_4
# 2022-10-26 17:02:43,004 INFO:Crawling: https://www.imdb.com/video/vi1084343577/?listId=ls025720609&ref_=hm_edcio_og_ots_thewatcher_5_i
# 2022-10-26 17:02:43,933 INFO:Crawling: https://www.imdb.com/video/vi1084343577/?listId=ls025720609&ref_=hm_edcio_og_ots_thewatcher_5_t
# 2022-10-26 17:02:44,831 INFO:Crawling: https://www.imdb.com/video/vi1203356953/?listId=ls025720609&ref_=hm_edcio_og_bq_ba_7_i
# 2022-10-26 17:02:45,767 INFO:Crawling: https://www.imdb.com/video/vi1203356953/?listId=ls025720609&ref_=hm_edcio_og_bq_ba_7_t
# 2022-10-26 17:02:46,777 INFO:Crawling: https://www.imdb.com/video/vi1537328409/?listId=ls025720609&ref_=hm_edcio_org_banshees_ots_11_i
# 2022-10-26 17:02:47,736 INFO:Crawling: https://www.imdb.com/video/vi1537328409/?listId=ls025720609&ref_=hm_edcio_org_banshees_ots_11_t
# 2022-10-26 17:02:48,677 INFO:Crawling: https://www.imdb.com/video/vi3749757721/?listId=ls025720609&ref_=hm_edcio_og_rtcml_jlc_13_i
# 2022-10-26 17:02:49,622 INFO:Crawling: https://www.imdb.com/video/vi3749757721/?listId=ls025720609&ref_=hm_edcio_og_rtcml_jlc_13_t
# 2022-10-26 17:02:50,686 INFO:Crawling: https://www.imdb.com/video/vi1497874969/?listId=ls025720609&ref_=hm_edcio_og_nsp_ada_15_i
# 2022-10-26 17:02:51,729 INFO:Crawling: https://www.imdb.com/video/vi1497874969/?listId=ls025720609&ref_=hm_edcio_og_nsp_ada_15_t
# 2022-10-26 17:02:52,527 INFO:Crawling: https://www.imdb.com/video/vi331072793/?listId=ls025720609&ref_=hm_edcio_org_hweenends_ots_17_i
# 2022-10-26 17:02:53,491 INFO:Crawling: https://www.imdb.com/video/vi331072793/?listId=ls025720609&ref_=hm_edcio_org_hweenends_ots_17_t
# 2022-10-26 17:02:54,452 INFO:Crawling: https://www.imdb.com/video/vi2964440345/?listId=ls025720609&ref_=hm_edcio_og_bq_lyle_19_i
# 2022-10-26 17:02:55,761 INFO:Crawling: https://www.imdb.com/video/vi2964440345/?listId=ls025720609&ref_=hm_edcio_og_bq_lyle_19_t
# 2022-10-26 17:02:56,946 INFO:Crawling: https://www.imdb.com/video/vi1314636313/?listId=ls025720609&ref_=hm_edcio_og_ots_werewolfbynight_21_i
# 2022-10-26 17:05:49,948 INFO:Crawling: https://www.imdb.com/title/tt12193804/?ref_=rlm
# 2022-10-26 17:05:51,918 INFO:Crawling: https://www.imdb.com/title/tt10640346/?ref_=rlm
# 2022-10-26 17:05:53,875 INFO:Crawling: https://www.imdb.com/title/tt11992694/?ref_=rlm
# 2022-10-26 17:05:57,736 INFO:Crawling: https://www.imdb.com/title/tt13230314/?ref_=rlm
# 2022-10-26 17:05:59,090 INFO:Crawling: https://www.imdb.com/title/tt13669038/?ref_=rlm
# 2022-10-26 17:06:01,215 INFO:Crawling: https://www.imdb.com/title/tt19433106/?ref_=rlm
# 2022-10-26 17:06:03,008 INFO:Crawling: https://www.imdb.com/title/tt17158126/?ref_=rlm
# 2022-10-26 17:06:04,768 INFO:Crawling: https://www.imdb.com/title/tt14532482/?ref_=rlm
# 2022-10-26 17:06:06,751 INFO:Crawling: https://www.imdb.com/title/tt7643430/?ref_=rlm
# 2022-10-26 17:06:09,136 INFO:Crawling: https://www.imdb.com/title/tt20258370/?ref_=rlm
# 2022-10-26 17:06:11,081 INFO:Crawling: https://www.imdb.com/title/tt8708518/?ref_=rlm
# 2022-10-26 17:06:12,814 INFO:Crawling: https://www.imdb.com/title/tt16754906/?ref_=rlm
# 2022-10-26 17:06:14,590 INFO:Crawling: https://www.imdb.com/title/tt12698678/?ref_=rlm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8300/2649263973.py in <module>
# ----> 1 Crawler(urls=['https://www.imdb.com/']).run()
#
# ~\AppData\Local\Temp/ipykernel_8300/1332209346.py in run(self)
#      30             logging.info(f'Crawling: {url}')
#      31             try:
# ---> 32                 self.crawl(url)
#      33             except Exception:
#      34                 logging.exception(f'Failed to crawl: {url}')
#
# ~\AppData\Local\Temp/ipykernel_8300/1332209346.py in crawl(self, url)
#      21
#      22     def crawl(self, url):
# ---> 23         html = self.download_url(url)
#      24         for url in self.get_linked_urls(url, html):
#      25             self.add_url_to_visit(url)
#
# ~\AppData\Local\Temp/ipykernel_8300/1332209346.py in download_url(self, url)
#       6
#       7     def download_url(self, url):
# ----> 8         return requests.get(url).text
#       9
#      10     def get_linked_urls(self, url, html):
#
# ~\anaconda3\envs\pandas\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\envs\pandas\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\envs\pandas\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\envs\pandas\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\pandas\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~\anaconda3\envs\pandas\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\envs\pandas\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\pandas\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\pandas\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\pandas\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\anaconda3\envs\pandas\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\anaconda3\envs\pandas\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\anaconda3\envs\pandas\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\envs\pandas\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\envs\pandas\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
